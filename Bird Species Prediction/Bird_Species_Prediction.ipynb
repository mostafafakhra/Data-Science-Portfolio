# %% [markdown]
# # Bird Species Prediction

# %% [markdown]
# In this project, I will create a Convolutional Neural Network which will be able to predict species of the bird. I will use different layers and other hyperparameters for building, training and testing this multiclass classifictaion model. I will be using keras for this project.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# First, I will mount my google drive on colab so that I can use the dataset directly from my drive. For this, I will first need to upload the data on my drive and then mount the drive on colab.

# %%
# After executing the cell above, Drive files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# 'Bird Speciees Dataset'  'Google Photos'
# 'Colab Notebooks'	 'Renegade X (64-bit, DX9) 2021-05-28 20-48-22.mp4'
# 'Copy of IMG_7247.JPG'	 'Untitled map.gmap'
# 'Copy of IMG_7249.JPG'

# %% [markdown]
# After mounting my drive, I will locate the folder where my data is stored to use it in my colab notebook. Here we can see that all the folders I have in my drive and 'Bird Species Dataset' contains the images that I will work on.

# %%
# Library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# I will start by importing some required libraries.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Bird Speciees Dataset/AMERICAN GOLDFINCH"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Let's visualize some of the bird images that I will be working on. Also I will observe x and y dimensions of the image.

# %%
# Setting path and creating empty list
dir = "/content/drive/My Drive/Bird Speciees Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %% [markdown]
# Setting the root directory for the dataset and storing all the floders name of the dataset. I will also create 2 empty list for image and lables.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# Next, I will read all the images and convert them into array and appending the list created above with the imaged and their label.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# dtype: int64

# %% [markdown]
# Check for class imbalance.

# %%
# Storing number of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Next, I will find out the number of classes that I will be working on.

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %% [markdown]
# Checking the size of the single image.

# %%
# Checking labels shape 
label_list = np.array(label_list)
label_list.shape
# Out:
# (811,)

# %% [markdown]
# Checking the shape of image labels which will be equal to the number of images I'm going to work with.

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now I will split the data into training and testing using train_test_split() of sklearn.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 224,224,3)
x_test = x_test.reshape( -1, 224,224,3)

# %% [markdown]
# Next I will normalize the images by dividing them with 255. Also, I will reshape x_train and x_test.

# %%
# Label binarizing
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %% [markdown]
# Next I will use label binarizer to one hot encode our y data. I will also print the sequence of the classes.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Now I will split the training data to validation and training data.

# %%
# Building model architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 224, 224, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 74, 74, 16)        1168
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 32)                331808
#
#  dense_1 (Dense)             (None, 6)                 198
#
# ...
# Total params: 338,038
# Trainable params: 338,038
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next I will create a network architecture for the model. I have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel). In the last layer, I will use softmax as the activation function because it is a multi class classification problem.

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %% [markdown]
# While compiling the model, I need to set the type of loss which will be Categorical Crossentropy for my model. Alongwith this, I also need to set the optimizer and the metrics respectively.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.7690 - accuracy: 0.2066 - val_loss: 1.6954 - val_accuracy: 0.2308
# Epoch 2/50
# 5/5 [==============================] - 10s 2s/step - loss: 1.6797 - accuracy: 0.2896 - val_loss: 1.6015 - val_accuracy: 0.3385
# Epoch 3/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.5610 - accuracy: 0.3900 - val_loss: 1.4700 - val_accuracy: 0.3769
# Epoch 4/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.4182 - accuracy: 0.5483 - val_loss: 1.3823 - val_accuracy: 0.4846
# Epoch 5/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.2941 - accuracy: 0.5347 - val_loss: 1.2042 - val_accuracy: 0.5846
# Epoch 6/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.1982 - accuracy: 0.5888 - val_loss: 1.1185 - val_accuracy: 0.5769
# Epoch 7/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.0170 - accuracy: 0.6950 - val_loss: 1.1320 - val_accuracy: 0.5538
# ...

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now, I will train my model on 50 epochs and a batch size of 128. I can try using more number of epochs to increase accuracy but here we can see that the model has already reached a very high accuracy so I don't need to run it for more. During each epochs, we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Saving model
model.save("/content/drive/My Drive/bird_species.h5")

# %% [markdown]
# Now we will save the model in h5 format to use it later for prediction.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next, I will plot the accuracy of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Here, I will plot the loss of the model for the training history.

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 6/6 [==============================] - 1s 202ms/step - loss: 0.5444 - accuracy: 0.8037
# Test Accuracy: 80.3680956363678

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Storing predictions
y_pred = model.predict(x_test)

# %% [markdown]
# Here, I'm storing prediction on test data.

# %%
# Plotting image to compare
img = array_to_img(x_test[5])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FBAE5C6F6D0>

# %% [markdown]
# Visualizing one of the images which I will be using for prediction.

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[5])])
print("Predicted : ",labels[np.argmax(y_pred[5])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  AMERICAN GOLDFINCH
# Predicted :  AMERICAN GOLDFINCH

# %% [markdown]
# Now, I will create list of labels using object of label binarizer. I will print that list and finally I will print out the prediction and the original label of the image I visualized above using argmax().

# %% [markdown]
# # Conclusion

# %% [markdown]
# I started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that, I created a CNN Model which is further used for predicting the bird species using the image supplied to model.
